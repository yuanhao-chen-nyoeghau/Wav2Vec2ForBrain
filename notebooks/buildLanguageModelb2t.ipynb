# %% [markdown]
# ## Step 0: Prerequisite
#
# To run this notebook, you need to build the decoder binaries and runtime first. Please refer to [README.md](../LanguageModelDecoder/README.md) for more details.
#
# You will need at least **230GB** of free disk space and **100GB** of RAM to run this notebook.

# %% [markdown]
# ## Step 1: Prepare language model training corpus.
#
# The training corpus should be a text file with one sentence per line. Here we use [OpenWebText2](https://openwebtext2.readthedocs.io/en/latest/) as an example.

# %%
# %%sh
#
# CORPUS_DIR=/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_corpus

# %% [markdown]
# Now we need to concatenate all the text files into one big file.
# Make sure you have python libraries `zstandard`, `jsonlines`, and `tqdm` installed.

# %%
import datetime
from tqdm.notebook import tqdm

def json_serial(obj):
    """JSON serializer for objects not serializable by default json code"""

    if isinstance(obj, (datetime.datetime,)):
        return obj.isoformat()
    raise TypeError ("Type %s not serializable" % type(obj))

merged_text_path = '/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_corpus/dataset.txt'

import json
from typing import Literal, Optional, cast
from datasets import load_dataset
import os

cache_dir = '/hpi/fs00/scratch/leon.hermann/b2t/cache'

sentences = cast(
                list[str],
                load_dataset(
                    "generics_kb",
                    "generics_kb_best",
                    cache_dir=cache_dir,
                    data_dir=os.path.join(os.path.join(cache_dir, "generics_kb_best"),"data"),
                    split="train",
                )[  # type: ignore
                    "generic_sentence"
                ],
            )

def write_sentences_to_file(sentences, filename):
    with open(filename, 'w') as file:
        for sentence in tqdm(sentences):
            file.write(json.dumps({"text":sentence, "meta": None}, default=json_serial) + "\n")

write_sentences_to_file(sentences, merged_text_path)
print(f"Sentences have been written to '{merged_text_path}'")
# Out:
# 100%|██████████| 1020868/1020868 [00:07<00:00, 130664.62it/s]
# Sentences have been written to '/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_corpus/openwebtext2.txt'

# %% [markdown]
# ## Step 2: Download CMU dictionary

# %%
# %%bash
#
# wget https://github.com/Alexir/CMUdict/raw/master/cmudict-0.7b -O /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_corpus/cmudict.txt
# Out:
# --2024-03-13 14:18:59--  https://github.com/Alexir/CMUdict/raw/master/cmudict-0.7b
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Alexir/CMUdict/master/cmudict-0.7b [following]
# --2024-03-13 14:18:59--  https://raw.githubusercontent.com/Alexir/CMUdict/master/cmudict-0.7b
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3865710 (3.7M) [text/plain]
# Saving to: ‘/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_corpus/cmudict.txt’
#
#      0K .......... .......... .......... .......... ..........  1% 2.49M 1s
#     50K .......... .......... .......... .......... ..........  2% 8.97M 1s
#    100K .......... .......... .......... .......... ..........  3% 5.32M 1s
#    150K .......... .......... .......... .......... ..........  5% 10.3M 1s
#    200K .......... .......... .......... .......... ..........  6% 3.98M 1s
#    250K .......... .......... .......... .......... ..........  7% 30.5M 1s
#    300K .......... .......... .......... .......... ..........  9% 31.9M 1s
#    350K .......... .......... .......... .......... .......... 10% 19.7M 0s
#    400K .......... .......... .......... .......... .......... 11% 37.1M 0s
#    450K .......... .......... .......... .......... .......... 13% 6.61M 0s
#    500K .......... .......... .......... .......... .......... 14% 59.1M 0s
#    550K .......... .......... .......... .......... .......... 15% 21.5M 0s
#    600K .......... .......... .......... .......... .......... 17% 29.4M 0s
#    650K .......... .......... .......... .......... .......... 18% 60.4M 0s
#    700K .......... .......... .......... .......... .......... 19% 33.5M 0s
#    750K .......... .......... .......... .......... .......... 21% 48.9M 0s
#    800K .......... .......... .......... .......... .......... 22% 69.9M 0s
#    850K .......... .......... .......... .......... .......... 23% 71.8M 0s
#    900K .......... .......... .......... .......... .......... 25% 49.6M 0s
#    950K .......... .......... .......... .......... .......... 26% 8.03M 0s
#   1000K .......... .......... .......... .......... .......... 27% 56.7M 0s
#   1050K .......... .......... .......... .......... .......... 29% 21.3M 0s
#   1100K .......... .......... .......... .......... .......... 30% 61.6M 0s
#   1150K .......... .......... .......... .......... .......... 31% 52.0M 0s
#   1200K .......... .......... .......... .......... .......... 33%  163M 0s
#   1250K .......... .......... .......... .......... .......... 34% 41.5M 0s
#   1300K .......... .......... .......... .......... .......... 35% 47.1M 0s
#   1350K .......... .......... .......... .......... .......... 37% 48.2M 0s
#   1400K .......... .......... .......... .......... .......... 38% 52.7M 0s
#   1450K .......... .......... .......... .......... .......... 39% 70.1M 0s
#   1500K .......... .......... .......... .......... .......... 41%  172M 0s
#   1550K .......... .......... .......... .......... .......... 42% 43.4M 0s
#   1600K .......... .......... .......... .......... .......... 43%  179M 0s
#   1650K .......... .......... .......... .......... .......... 45% 47.9M 0s
#   1700K .......... .......... .......... .......... .......... 46% 68.7M 0s
#   1750K .......... .......... .......... .......... .......... 47%  191M 0s
#   1800K .......... .......... .......... .......... .......... 49% 27.9M 0s
#   1850K .......... .......... .......... .......... .......... 50%  227M 0s
#   1900K .......... .......... .......... .......... .......... 51% 40.3M 0s
#   1950K .......... .......... .......... .......... .......... 52% 11.9M 0s
#   2000K .......... .......... .......... .......... .......... 54% 51.2M 0s
#   2050K .......... .......... .......... .......... .......... 55% 84.6M 0s
#   2100K .......... .......... .......... .......... .......... 56% 47.8M 0s
#   2150K .......... .......... .......... .......... .......... 58% 33.8M 0s
#   2200K .......... .......... .......... .......... .......... 59%  215M 0s
#   2250K .......... .......... .......... .......... .......... 60% 27.9M 0s
#   2300K .......... .......... .......... .......... .......... 62% 64.7M 0s
#   2350K .......... .......... .......... .......... .......... 63% 54.7M 0s
#   2400K .......... .......... .......... .......... .......... 64% 44.8M 0s
#   2450K .......... .......... .......... .......... .......... 66%  194M 0s
#   2500K .......... .......... .......... .......... .......... 67%  169M 0s
#   2550K .......... .......... .......... .......... .......... 68% 23.5M 0s
#   2600K .......... .......... .......... .......... .......... 70% 7.90M 0s
#   2650K .......... .......... .......... .......... .......... 71%  188M 0s
#   2700K .......... .......... .......... .......... .......... 72%  234M 0s
#   2750K .......... .......... .......... .......... .......... 74%  173M 0s
#   2800K .......... .......... .......... .......... .......... 75%  220M 0s
#   2850K .......... .......... .......... .......... .......... 76%  186M 0s
#   2900K .......... .......... .......... .......... .......... 78%  174M 0s
#   2950K .......... .......... .......... .......... .......... 79%  192M 0s
#   3000K .......... .......... .......... .......... .......... 80% 2.47M 0s
#   3050K .......... .......... .......... .......... .......... 82%  105M 0s
#   3100K .......... .......... .......... .......... .......... 83%  199M 0s
#   3150K .......... .......... .......... .......... .......... 84% 16.5M 0s
#   3200K .......... .......... .......... .......... .......... 86%  137M 0s
#   3250K .......... .......... .......... .......... .......... 87%  150M 0s
#   3300K .......... .......... .......... .......... .......... 88%  210M 0s
#   3350K .......... .......... .......... .......... .......... 90%  172M 0s
#   3400K .......... .......... .......... .......... .......... 91%  140M 0s
#   3450K .......... .......... .......... .......... .......... 92%  213M 0s
#   3500K .......... .......... .......... .......... .......... 94%  218M 0s
#   3550K .......... .......... .......... .......... .......... 95%  239M 0s
#   3600K .......... .......... .......... .......... .......... 96% 5.34M 0s
#   3650K .......... .......... .......... .......... .......... 98% 20.8M 0s
#   3700K .......... .......... .......... .......... .......... 99%  164M 0s
#   3750K .......... .......... .....                           100%  318M=0.2s
#
# 2024-03-13 14:19:00 (23.1 MB/s) - ‘/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_corpus/cmudict.txt’ saved [3865710/3865710]

# %% [markdown]
# ## Step 3: Build language model
#
# Build a 3-gram language model based on the OpenWebText2 corpus.

# %%
# %%bash
#
# set -xe
#
# LM_ROOT=../LanguageModelDecoder/examples/speech/s0/
# LM_CORPUS_DIR=/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_corpus
# LM_MODEL_DIR=/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model
#
# cd $LM_ROOT
# echo $PWD
# . path.sh
#
# # First step is formatting the text corpus.
# mkdir -p $LM_MODEL_DIR/data/local/lm_data
# python local/format_lm_data.py \
#     --input_text $LM_CORPUS_DIR/openwebtext2.txt \
#     --output_text $LM_MODEL_DIR/data/local/lm_data/corpus.txt \
#     --dict $LM_CORPUS_DIR/cmudict.txt \
#     --unk
#
# # Build the LM
# dict_type=phn
# lm_order=3
# prune_threshold=1e-9
# local/build_lm.sh \
#     $LM_MODEL_DIR/data/local/lm_data/corpus.txt \
#     $LM_MODEL_DIR/data/local/lm \
#     $dict_type \
#     $lm_order \
#     $prune_threshold \
#     $LM_CORPUS_DIR/cmudict.txt
#
# # Optionally, if you have 1TB of RAM, you can build a 5-gram LM
# #dict_type=phn
# #lm_order=5
# #prune_threshold=4e-11
# #local/build_lm.sh \
# #    $LM_MODEL_DIR/data/local/lm_data/corpus.txt \
# #    $LM_MODEL_DIR/data/local/lm \
# #    $dict_type \
# #    $lm_order \
# #    $prune_threshold \
# #    $LM_CORPUS_DIR/cmudict.txt
# Out:
# + LM_ROOT=../LanguageModelDecoder/examples/speech/s0/
# + LM_CORPUS_DIR=/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_corpus
# + LM_MODEL_DIR=/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model
# + cd ../LanguageModelDecoder/examples/speech/s0/
# + echo /hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0
# + . path.sh
# /hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0
# ++ export WENET_DIR=/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../..
# ++ WENET_DIR=/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../..
# ++ export BUILD_DIR=/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build
# ++ BUILD_DIR=/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build
# ++ export OPENFST_PREFIX_DIR=/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build/../fc_base/openfst-subbuild/openfst-populate-prefix
# ++ OPENFST_PREFIX_DIR=/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build/../fc_base/openfst-subbuild/openfst-populate-prefix
# ++ export PATH=/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build/kaldi:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build/../fc_base/openfst-subbuild/openfst-populate-prefix/bin:/hpi/fs00/home/leon.hermann/mambaforge/envs/b2t/bin:/hpi/fs00/home/leon.hermann/.vscode-server/bin/863d2581ecda6849923a2118d93a088b0745d9d6/bin/remote-cli:/hpi/fs00/home/leon.hermann/mambaforge/envs/b2t/bin:/hpi/fs00/home/leon.hermann/mambaforge/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/hpi/fs00/home/leon.hermann/.local/bin:/hpi/fs00/home/leon.hermann/bin
# ++ PATH=/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build/kaldi:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build/../fc_base/openfst-subbuild/openfst-populate-prefix/bin:/hpi/fs00/home/leon.hermann/mambaforge/envs/b2t/bin:/hpi/fs00/home/leon.hermann/.vscode-server/bin/863d2581ecda6849923a2118d93a088b0745d9d6/bin/remote-cli:/hpi/fs00/home/leon.hermann/mambaforge/envs/b2t/bin:/hpi/fs00/home/leon.hermann/mambaforge/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/hpi/fs00/home/leon.hermann/.local/bin:/hpi/fs00/home/leon.hermann/bin
# ++ export PATH=/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build/kaldi:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build/../fc_base/openfst-subbuild/openfst-populate-prefix/bin:/hpi/fs00/home/leon.hermann/mambaforge/envs/b2t/bin:/hpi/fs00/home/leon.hermann/.vscode-server/bin/863d2581ecda6849923a2118d93a088b0745d9d6/bin/remote-cli:/hpi/fs00/home/leon.hermann/mambaforge/envs/b2t/bin:/hpi/fs00/home/leon.hermann/mambaforge/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/hpi/fs00/home/leon.hermann/.local/bin:/hpi/fs00/home/leon.hermann/bin:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../srilm-1.7.3/bin/i686-m64
# ++ PATH=/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build/kaldi:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../runtime/server/x86/build/../fc_base/openfst-subbuild/openfst-populate-prefix/bin:/hpi/fs00/home/leon.hermann/mambaforge/envs/b2t/bin:/hpi/fs00/home/leon.hermann/.vscode-server/bin/863d2581ecda6849923a2118d93a088b0745d9d6/bin/remote-cli:/hpi/fs00/home/leon.hermann/mambaforge/envs/b2t/bin:/hpi/fs00/home/leon.hermann/mambaforge/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/hpi/fs00/home/leon.hermann/.local/bin:/hpi/fs00/home/leon.hermann/bin:/hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/../../../srilm-1.7.3/bin/i686-m64
# ++ export PYTHONIOENCODING=UTF-8
# ++ PYTHONIOENCODING=UTF-8
# ++ export PYTHONPATH=../../::/hpi/fs00/home/leon.hermann/brain2text/src:/hpi/fs00/home/leon.hermann/brain2text/src:/hpi/fs00/home/leon.hermann/brain2text/src
# ++ PYTHONPATH=../../::/hpi/fs00/home/leon.hermann/brain2text/src:/hpi/fs00/home/leon.hermann/brain2text/src:/hpi/fs00/home/leon.hermann/brain2text/src
# + mkdir -p /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/local/lm_data
# + python local/format_lm_data.py --input_text /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_corpus/openwebtext2.txt --output_text /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/local/lm_data/corpus.txt --dict /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_corpus/cmudict.txt --unk
# /hpi/fs00/home/leon.hermann/brain2text/speechBCI/LanguageModelDecoder/examples/speech/s0/local/format_lm_data.py:38: SyntaxWarning: invalid escape sequence '\-'
#   modifiedText = re.sub("[^a-z .',?\-]", '', modifiedText.lower())
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# + dict_type=phn
# + lm_order=3
# + prune_threshold=1e-9
# + local/build_lm.sh /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/local/lm_data/corpus.txt /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/local/lm phn 3 1e-9 /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_corpus/cmudict.txt
# /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/local/lm
# /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/local/lm_data/corpus.txt: line 2011970: 2011905 sentences, 11315212 words, 407976 OOVs
# 0 zeroprobs, logprob= 0 ppl= 1 ppl1= 1
# using GoodTuring for 1-grams
# Good-Turing discounting 1-grams
# GT-count [0] = 0
# GT-count [1] = 7473
# GT-count [2] = 3879
# warning: discount coeff 1 is out of range: -0
# using GoodTuring for 2-grams
# Good-Turing discounting 2-grams
# GT-count [0] = 0
# GT-count [1] = 725223
# GT-count [2] = 178938
# GT-count [3] = 79277
# GT-count [4] = 49006
# GT-count [5] = 31889
# GT-count [6] = 23070
# GT-count [7] = 17471
# GT-count [8] = 13809
# using GoodTuring for 3-grams
# Good-Turing discounting 3-grams
# GT-count [0] = 0
# GT-count [1] = 2802009
# GT-count [2] = 441695
# GT-count [3] = 150385
# GT-count [4] = 85115
# GT-count [5] = 48133
# GT-count [6] = 32625
# GT-count [7] = 23154
# GT-count [8] = 17428
# warning: -3.59712e-14 backoff probability mass left for "" -- incrementing denominator
# warning: 7.50348e-08 backoff probability mass left for "" -- incrementing denominator
# warning: 1.5007e-07 backoff probability mass left for "" -- incrementing denominator
# warning: 2.25105e-07 backoff probability mass left for "" -- incrementing denominator
# warning: 3.0014e-07 backoff probability mass left for "" -- incrementing denominator
# warning: 3.75175e-07 backoff probability mass left for "" -- incrementing denominator
# warning: 4.5021e-07 backoff probability mass left for "" -- incrementing denominator
# warning: 5.25244e-07 backoff probability mass left for "" -- incrementing denominator
# warning: 6.00279e-07 backoff probability mass left for "" -- incrementing denominator
# warning: 6.75315e-07 backoff probability mass left for "" -- incrementing denominator
# warning: 7.5035e-07 backoff probability mass left for "" -- incrementing denominator
# warning: 8.25384e-07 backoff probability mass left for "" -- incrementing denominator
# warning: 9.00419e-07 backoff probability mass left for "" -- incrementing denominator
# warning: 9.75454e-07 backoff probability mass left for "" -- incrementing denominator
# warning: 1.05049e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 1.12552e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 1.20056e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 1.27559e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 1.35063e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 1.42566e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 1.5007e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 1.57573e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 1.65077e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 1.7258e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 1.80084e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 1.87587e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 1.95091e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.02594e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.10098e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.17601e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.25104e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.32608e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.40111e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.47615e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.55118e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.62622e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.70125e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.77629e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.85132e-06 backoff probability mass left for "" -- incrementing denominator
# warning: 2.92636e-06 backoff probability mass left for "" -- incrementing denominator
# warning: distributing 0 left-over probability mass over 91685 zeroton words
# warning: 0 backoff probability mass left for "KASHA" -- incrementing denominator
# warning: 0 backoff probability mass left for "KARNAL" -- incrementing denominator
# warning: 0 backoff probability mass left for "CAPITALIZE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ROULETTE" -- incrementing denominator
# warning: 0 backoff probability mass left for "AKIN" -- incrementing denominator
# warning: 0 backoff probability mass left for "AFTERMATH" -- incrementing denominator
# warning: 0 backoff probability mass left for "WIDOW'S" -- incrementing denominator
# warning: 0 backoff probability mass left for "TYPIFIED" -- incrementing denominator
# warning: 0 backoff probability mass left for "WARDING" -- incrementing denominator
# warning: 0 backoff probability mass left for "HEADMISTRESSES" -- incrementing denominator
# warning: 0 backoff probability mass left for "SIRS" -- incrementing denominator
# warning: 0 backoff probability mass left for "REMINISCENT" -- incrementing denominator
# warning: 0 backoff probability mass left for "COULD" -- incrementing denominator
# warning: 0 backoff probability mass left for "OBSESSED" -- incrementing denominator
# warning: 0 backoff probability mass left for "STILETTOS" -- incrementing denominator
# warning: 0 backoff probability mass left for "GLUTAMIC" -- incrementing denominator
# warning: 0 backoff probability mass left for "FENG" -- incrementing denominator
# warning: 0 backoff probability mass left for "COINCIDES" -- incrementing denominator
# warning: 0 backoff probability mass left for "BARITONES" -- incrementing denominator
# warning: 0 backoff probability mass left for "FREEMEN" -- incrementing denominator
# warning: 0 backoff probability mass left for "WOULD" -- incrementing denominator
# warning: 0 backoff probability mass left for "CARBOXYLIC" -- incrementing denominator
# warning: 0 backoff probability mass left for "HYALURONIC" -- incrementing denominator
# warning: 0 backoff probability mass left for "SEATO" -- incrementing denominator
# warning: 0 backoff probability mass left for "SOPRANO" -- incrementing denominator
# warning: 0 backoff probability mass left for "SPECIALIZES" -- incrementing denominator
# warning: 0 backoff probability mass left for "SYNDICATION" -- incrementing denominator
# warning: 0 backoff probability mass left for "MIDST" -- incrementing denominator
# warning: 0 backoff probability mass left for "ASCORBIC" -- incrementing denominator
# warning: 0 backoff probability mass left for "IRRESPECTIVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "GUZZLERS" -- incrementing denominator
# warning: 0 backoff probability mass left for "DOBSONS" -- incrementing denominator
# warning: 0 backoff probability mass left for "VOLITION" -- incrementing denominator
# warning: 0 backoff probability mass left for "LIKENED" -- incrementing denominator
# warning: 0 backoff probability mass left for "MORSE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SILLS" -- incrementing denominator
# warning: 0 backoff probability mass left for "SHOULD" -- incrementing denominator
# warning: 0 backoff probability mass left for "OBITUARIES" -- incrementing denominator
# warning: 0 backoff probability mass left for "PERTAINING" -- incrementing denominator
# warning: 0 backoff probability mass left for "PERCHLORIC" -- incrementing denominator
# warning: 0 backoff probability mass left for "PEDESTALS" -- incrementing denominator
# warning: 0 backoff probability mass left for "UNHEARD" -- incrementing denominator
# warning: 0 backoff probability mass left for "AIRCRAFTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "STEMMING" -- incrementing denominator
# warning: 0 backoff probability mass left for "AREN" -- incrementing denominator
# warning: 0 backoff probability mass left for "MUST" -- incrementing denominator
# warning: 0 backoff probability mass left for "TWEED" -- incrementing denominator
# warning: 0 backoff probability mass left for "PAPUA" -- incrementing denominator
# warning: 0 backoff probability mass left for "HARBINGERS" -- incrementing denominator
# warning: 0 backoff probability mass left for "TURNSTILES" -- incrementing denominator
# warning: 0 backoff probability mass left for "STEARIC" -- incrementing denominator
# warning: 0 backoff probability mass left for "BABY-SITTERS" -- incrementing denominator
# warning: 0 backoff probability mass left for "PARSIMONY" -- incrementing denominator
# warning: 0 backoff probability mass left for "PALACES" -- incrementing denominator
# warning: 0 backoff probability mass left for "AFORETHOUGHT" -- incrementing denominator
# warning: 0 backoff probability mass left for "LIEU" -- incrementing denominator
# warning: 0 backoff probability mass left for "UNWILLINGNESS" -- incrementing denominator
# warning: 0 backoff probability mass left for "SWITCHBOARD" -- incrementing denominator
# warning: 0 backoff probability mass left for "NORPLANT" -- incrementing denominator
# warning: 0 backoff probability mass left for "THEREOF" -- incrementing denominator
# warning: 0 backoff probability mass left for "BOULEVARDS" -- incrementing denominator
# warning: 0 backoff probability mass left for "REPLETE" -- incrementing denominator
# warning: 0 backoff probability mass left for "VODKAS" -- incrementing denominator
# warning: 0 backoff probability mass left for "DEVOID" -- incrementing denominator
# warning: 0 backoff probability mass left for "STRINGED" -- incrementing denominator
# warning: 0 backoff probability mass left for "BACKDROPS" -- incrementing denominator
# warning: 0 backoff probability mass left for "STEAKHOUSES" -- incrementing denominator
# discarded 1 2-gram contexts containing pseudo-events
# warning: 0 backoff probability mass left for "EACH WEIGHT" -- incrementing denominator
# warning: 0 backoff probability mass left for "EARTH SHARE" -- incrementing denominator
# warning: 0 backoff probability mass left for "KNOWLEDGE SHARE" -- incrementing denominator
# warning: 0 backoff probability mass left for "LANDSCAPES SHARE" -- incrementing denominator
# warning: 0 backoff probability mass left for "HABITATS SHARE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ENVIRONMENTS SHARE" -- incrementing denominator
# warning: 0 backoff probability mass left for "PATTERNS SHARE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ANCESTORS SHARE" -- incrementing denominator
# warning: 0 backoff probability mass left for "EXPERIENCE SHARE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SIMILARITY SHARE" -- incrementing denominator
# warning: 0 backoff probability mass left for "EXISTS MUSIC" -- incrementing denominator
# warning: 0 backoff probability mass left for "FOOD FLAKE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEND LEAVES" -- incrementing denominator
# warning: 0 backoff probability mass left for "DUE OCCUR" -- incrementing denominator
# warning: 0 backoff probability mass left for "SEEDS CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "HUNDREDS CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONCENTRATION CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "CITRIC CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "VESSELS CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "ELECTROLYTES CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "COMPONENTS CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "PHEROMONE CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "POLLUTANTS CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "IRONS CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "TREES CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "PRODUCTS CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "NITRATE CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "AMOUNTS CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "HORMONES CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "DIGESTIVE CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "ATOMS CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "PHOSPHORUS CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "YEAST CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "LOTS CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "DIOXIDE CONTAINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "INTO MOUTH" -- incrementing denominator
# warning: 0 backoff probability mass left for "LEVELS TURBIDITY" -- incrementing denominator
# warning: 0 backoff probability mass left for "LEADS TEMPERATURE" -- incrementing denominator
# warning: 0 backoff probability mass left for "AWAY TEMPERATURE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TOLERANCE TEMPERATURE" -- incrementing denominator
# warning: 0 backoff probability mass left for "RELATES AILMENT" -- incrementing denominator
# warning: 0 backoff probability mass left for "FEET WEB" -- incrementing denominator
# warning: 0 backoff probability mass left for "FIND MINERALS" -- incrementing denominator
# warning: 0 backoff probability mass left for "SUCH MINERALS" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE MAIDS" -- incrementing denominator
# warning: 0 backoff probability mass left for "IS LEADER" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEND APHIDS" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE SOPHISTICATES" -- incrementing denominator
# warning: 0 backoff probability mass left for "AREAS SHADE" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAS CANADA" -- incrementing denominator
# warning: 0 backoff probability mass left for "GRAZE LLAMAS" -- incrementing denominator
# warning: 0 backoff probability mass left for "COME LLAMAS" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAS HAITIAN" -- incrementing denominator
# warning: 0 backoff probability mass left for "MINES PIT" -- incrementing denominator
# warning: 0 backoff probability mass left for "VOLUNTEERS CASA" -- incrementing denominator
# warning: 0 backoff probability mass left for "OUT GROWS" -- incrementing denominator
# warning: 0 backoff probability mass left for "MAKE CHAIRS" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE AUTOS" -- incrementing denominator
# warning: 0 backoff probability mass left for "SEEMS STRESS" -- incrementing denominator
# warning: 0 backoff probability mass left for "APPEARS STRESS" -- incrementing denominator
# warning: 0 backoff probability mass left for "CAUSED STRESS" -- incrementing denominator
# warning: 0 backoff probability mass left for "ALTERS STRESS" -- incrementing denominator
# warning: 0 backoff probability mass left for "REFERS FLEXIBILITY" -- incrementing denominator
# warning: 0 backoff probability mass left for "PASSES SUNLIGHT" -- incrementing denominator
# warning: 0 backoff probability mass left for "IS POSTSCRIPT" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONSISTS PHOTOSYNTHESIS" -- incrementing denominator
# warning: 0 backoff probability mass left for "SUCH PESTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "BELONG CUCUMBERS" -- incrementing denominator
# warning: 0 backoff probability mass left for "END PEOPLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DON PEOPLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DEAL PEOPLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MAY PEOPLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TOO PEOPLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "REFER PEOPLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TRYING PEOPLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONTINUE PEOPLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "OBJECT PEOPLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "WILL PEOPLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEND PEOPLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "X TWO" -- incrementing denominator
# warning: 0 backoff probability mass left for "KINDS TWO" -- incrementing denominator
# warning: 0 backoff probability mass left for "WHAT COMPUTER" -- incrementing denominator
# warning: 0 backoff probability mass left for "DOGS OWN" -- incrementing denominator
# warning: 0 backoff probability mass left for "SET OWN" -- incrementing denominator
# warning: 0 backoff probability mass left for "BURROWS OWN" -- incrementing denominator
# warning: 0 backoff probability mass left for "NAMES OWN" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONTINUES TECHNOLOGY" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAS PANAMANIAN" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE THIGHS" -- incrementing denominator
# warning: 0 backoff probability mass left for "EMERGE TERMITES" -- incrementing denominator
# warning: 0 backoff probability mass left for "WINGS FOLD" -- incrementing denominator
# warning: 0 backoff probability mass left for "LINES FUEL" -- incrementing denominator
# warning: 0 backoff probability mass left for "COMES FUEL" -- incrementing denominator
# warning: 0 backoff probability mass left for "INDICATORS FUEL" -- incrementing denominator
# warning: 0 backoff probability mass left for "GAUGES FUEL" -- incrementing denominator
# warning: 0 backoff probability mass left for "DENS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "NIPPLES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MINERALS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BONDS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "FLEXIBILITY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SUNLIGHT HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "WHEELS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ENEMIES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "GUTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CAVITIES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "PARTNERS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BREATHS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "PURPOSES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BARRELS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "INSTINCT HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ANIMALS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SAILS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "POSITIONS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "INSULATION HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "REPRODUCTION HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "VERTEBRAE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ROCK HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BREEDS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "COLORATION HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TENDONS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "OPTIONS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SHADES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "PRESENCE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ARTERIES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "HANDLES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "PANIC HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "RESEMBLANCE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ASPECTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "FOREHEADS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BLADES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "FIBRE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONCENTRATION HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "AGES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "COMPOUNDS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BIRDS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TINTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "INJURIES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "HOSTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "THICKNESS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SKULLS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CHAMBER HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BREAKS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ANTENNAS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MASTER HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SILKY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TUNNELS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "IDENTITIES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ADVANTAGE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "PERCEPTIONS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "FOLLICLES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CALLS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DETAILS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "INTESTINES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "FLOORS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "WIDTH HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CIRCUITS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "OUTPUT HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CHESTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "LIMITATIONS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "HABITS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CURVES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "VARIATION HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CORD HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BOTTOMS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CASES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "PUPILS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONCEPTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DISORDER HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "AROMA HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "POLICY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CANINE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BIOMASS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "FACTORS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "OPPORTUNITY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ENVIRONMENTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "APPETITE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "WORKERS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DEBTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "INTENTIONS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "FINGERS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TWICE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "OUTCOMES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "WAVES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SYMMETRY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MEALS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEXTURE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "STAGES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MAJORITIES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "VIRUSES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "APPEARANCES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONDUCTIVITY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SIGHT HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BLOTCHES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "UP HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SHELF HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MUTATION HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SENSE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "KINDS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONCERN HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CAPABILITY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "IRISES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TECHNIQUES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BELLIES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "STYLE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "RETRACTABLE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "RESULTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "FORELIMBS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DISTRIBUTION HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "STOMACHS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "RESPONSES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DEFICIENCIES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MIGRATION HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "AMOUNTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TIRES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SHOULDERS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "FORCES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BULBS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BIODIVERSITY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MORTALITY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "KERNELS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "GENUS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TYPES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CAPILLARIES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "LENSES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "METAMORPHOSIS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "INTERACTION HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MOUNTAINS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DIGITS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BACTERIA HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "PULSES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TRACTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "LIFESTYLE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "LICE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CHANCES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SONS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TAP HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "KIDNEYS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "RISK HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "METABOLISM HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DIVERSITY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "INFECTION HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "RAYS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "HEARTBEATS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SNOUTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BEDS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SOLUTIONS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BERRIES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "STIGMA HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MATES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CAPACITY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "EXPECTANCY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "PATHS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "AMONG HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TASKS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "STEMS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SIMILARITY HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CHARACTERS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "PRODUCTION HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "OVARIES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "STALKS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DRAINAGE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DIMENSIONS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "STORMS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "HUES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "AERIAL HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "THROATS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "STRING HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MAGNITUDES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SECRETION HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MUZZLES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TRUNKS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "COMPARTMENTS HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "INTAKE HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "NODES HAVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAS MALAY" -- incrementing denominator
# warning: 0 backoff probability mass left for "B <s>" -- incrementing denominator
# warning: 0 backoff probability mass left for "C <s>" -- incrementing denominator
# warning: 0 backoff probability mass left for "TUBERCULOSIS <s>" -- incrementing denominator
# warning: 0 backoff probability mass left for "META <s>" -- incrementing denominator
# warning: 1.01124e-06 backoff probability mass left for "META <s>" -- incrementing denominator
# warning: 2.02248e-06 backoff probability mass left for "META <s>" -- incrementing denominator
# warning: 0 backoff probability mass left for "SUCCESS INFLUENCE" -- incrementing denominator
# warning: 0 backoff probability mass left for "GROWTH INFLUENCE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CHOICES INFLUENCE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DISTRIBUTION INFLUENCE" -- incrementing denominator
# warning: 0 backoff probability mass left for "LEAD EVENTUALLY" -- incrementing denominator
# warning: 0 backoff probability mass left for "NUMBER HUGE" -- incrementing denominator
# warning: 0 backoff probability mass left for "AMOUNT HUGE" -- incrementing denominator
# warning: 0 backoff probability mass left for "OF BLINK" -- incrementing denominator
# warning: 0 backoff probability mass left for "DIFFERENT MEANS" -- incrementing denominator
# warning: 0 backoff probability mass left for "LOSS MEANS" -- incrementing denominator
# warning: 0 backoff probability mass left for "BY MEANS" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONSIST MUSCLES" -- incrementing denominator
# warning: 0 backoff probability mass left for "EFFECTS STUDY" -- incrementing denominator
# warning: 0 backoff probability mass left for "CHARACTERISTICS STUDY" -- incrementing denominator
# warning: 0 backoff probability mass left for "ON DISCRIMINATION" -- incrementing denominator
# warning: 0 backoff probability mass left for "LIKE PARENTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "OXYGEN ABSORBS" -- incrementing denominator
# warning: 0 backoff probability mass left for "RADIATION ABSORBS" -- incrementing denominator
# warning: 0 backoff probability mass left for "PART WORK" -- incrementing denominator
# warning: 0 backoff probability mass left for "CLOSELY WORK" -- incrementing denominator
# warning: 0 backoff probability mass left for "VERSIONS SMALLER" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE CAFES" -- incrementing denominator
# warning: 0 backoff probability mass left for "FIND CLAMS" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONSIST SEEDS" -- incrementing denominator
# warning: 0 backoff probability mass left for "LOOK SEEDS" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONSUMPTION ANIMAL" -- incrementing denominator
# warning: 0 backoff probability mass left for "WORLD ANIMAL" -- incrementing denominator
# warning: 0 backoff probability mass left for "SOON AS" -- incrementing denominator
# warning: 0 backoff probability mass left for "INSULATORS AS" -- incrementing denominator
# warning: 0 backoff probability mass left for "OPPOSED AS" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONCERN AS" -- incrementing denominator
# warning: 0 backoff probability mass left for "INDICATORS AS" -- incrementing denominator
# warning: 0 backoff probability mass left for "FILL CAVITIES" -- incrementing denominator
# warning: 0 backoff probability mass left for "CLASS SPECIAL" -- incrementing denominator
# warning: 0 backoff probability mass left for "TENDS GROWTH" -- incrementing denominator
# warning: 0 backoff probability mass left for "LEADS GROWTH" -- incrementing denominator
# warning: 0 backoff probability mass left for "SOURCE LARGEST" -- incrementing denominator
# warning: 0 backoff probability mass left for "SOURCES LARGEST" -- incrementing denominator
# warning: 0 backoff probability mass left for "MEMBERS LARGEST" -- incrementing denominator
# warning: 0 backoff probability mass left for "RETURN ANTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "ADAPT ANTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONSIST GROUPS" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEND GROUPS" -- incrementing denominator
# warning: 0 backoff probability mass left for "BASED GROUPS" -- incrementing denominator
# warning: 0 backoff probability mass left for "YEARS PASS" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEND SHEEP" -- incrementing denominator
# warning: 0 backoff probability mass left for "ADAPT SHEEP" -- incrementing denominator
# warning: 0 backoff probability mass left for "URINE CONCENTRATE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TAILS FLEXIBLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "MOON EARTH'S" -- incrementing denominator
# warning: 0 backoff probability mass left for "ON FOUNDATION" -- incrementing denominator
# warning: 0 backoff probability mass left for "UPON FOUNDATION" -- incrementing denominator
# warning: 0 backoff probability mass left for "OF EARNER" -- incrementing denominator
# warning: 0 backoff probability mass left for "FEED URCHINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "MAY BABIES" -- incrementing denominator
# warning: 0 backoff probability mass left for "LIKE BABIES" -- incrementing denominator
# warning: 0 backoff probability mass left for "BENEFIT BABIES" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEND BABIES" -- incrementing denominator
# warning: 0 backoff probability mass left for "DEPEND BABIES" -- incrementing denominator
# warning: 0 backoff probability mass left for "DIABETES UNCONTROLLED" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE TOMORROWS" -- incrementing denominator
# warning: 0 backoff probability mass left for "PURPOSES SERVE" -- incrementing denominator
# ...
# warning: 0 backoff probability mass left for "BOTTOMS FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "FACTORS FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "HEARTS FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "COUNTRY FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "ZOOS FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "MOTHERS FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "SITES FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "COLONIES FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "DEGREES FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "GENERATION FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "SEASON FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "PIGMENT FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "YEAR FROM" -- incrementing denominator
# warning: 0 backoff probability mass left for "ENVIRONMENTS OCCUPY" -- incrementing denominator
# warning: 0 backoff probability mass left for "TERRITORY OCCUPY" -- incrementing denominator
# warning: 0 backoff probability mass left for "RANGES OCCUPY" -- incrementing denominator
# warning: 0 backoff probability mass left for "BURROWS OCCUPY" -- incrementing denominator
# warning: 0 backoff probability mass left for "FORM POPULAR" -- incrementing denominator
# warning: 0 backoff probability mass left for "FORMS POPULAR" -- incrementing denominator
# warning: 0 backoff probability mass left for "LIFE LOSE" -- incrementing denominator
# warning: 0 backoff probability mass left for "WING LOSE" -- incrementing denominator
# warning: 0 backoff probability mass left for "LBS LOSE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ABILITY LOSE" -- incrementing denominator
# warning: 0 backoff probability mass left for "FEATHERS LOSE" -- incrementing denominator
# warning: 0 backoff probability mass left for "LIMBS LOSE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TENDS SOCIETY" -- incrementing denominator
# warning: 0 backoff probability mass left for "FRACTION SMALL" -- incrementing denominator
# warning: 0 backoff probability mass left for "SEA TEMPERATE" -- incrementing denominator
# warning: 0 backoff probability mass left for "IS HALL" -- incrementing denominator
# warning: 0 backoff probability mass left for "SUBSTITUTE POOR" -- incrementing denominator
# warning: 0 backoff probability mass left for "SIGHT POOR" -- incrementing denominator
# warning: 0 backoff probability mass left for "SENSE POOR" -- incrementing denominator
# warning: 0 backoff probability mass left for "GROWTH HELPS" -- incrementing denominator
# warning: 0 backoff probability mass left for "RID HELPS" -- incrementing denominator
# warning: 0 backoff probability mass left for "HEALTH HELPS" -- incrementing denominator
# warning: 0 backoff probability mass left for "PROBLEMS HELPS" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONSTIPATION HELPS" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE FRIGATES" -- incrementing denominator
# warning: 0 backoff probability mass left for "NIGHTS COLD" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE DIGGERS" -- incrementing denominator
# warning: 0 backoff probability mass left for "TAKES RESPIRATION" -- incrementing denominator
# warning: 0 backoff probability mass left for "GIVE OBJECTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "SUCH OBJECTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEND OBJECTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "ON NOVO" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE BARONS" -- incrementing denominator
# warning: 0 backoff probability mass left for "PROPORTION LARGER" -- incrementing denominator
# warning: 0 backoff probability mass left for "NUMBER LARGER" -- incrementing denominator
# warning: 0 backoff probability mass left for "THEIR VOLUNTEER" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAS SPAWN" -- incrementing denominator
# warning: 0 backoff probability mass left for "FORM EFFICIENT" -- incrementing denominator
# warning: 0 backoff probability mass left for "USE EFFICIENT" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEND WOLVES" -- incrementing denominator
# warning: 0 backoff probability mass left for "SURVIVE WOLVES" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEND WINDS" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEND DOES" -- incrementing denominator
# warning: 0 backoff probability mass left for "SEEM DOES" -- incrementing denominator
# warning: 0 backoff probability mass left for "FRESH DRINK" -- incrementing denominator
# warning: 0 backoff probability mass left for "FLUID DRINK" -- incrementing denominator
# warning: 0 backoff probability mass left for "LIVE EELS" -- incrementing denominator
# warning: 0 backoff probability mass left for "ASSOCIATED HAZARD" -- incrementing denominator
# warning: 0 backoff probability mass left for "<unk> GASOLINE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TANKS GASOLINE" -- incrementing denominator
# warning: 0 backoff probability mass left for "GAUGES GASOLINE" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE WIMPS" -- incrementing denominator
# warning: 0 backoff probability mass left for "PARENTS BECOME" -- incrementing denominator
# warning: 0 backoff probability mass left for "PART BECOME" -- incrementing denominator
# warning: 0 backoff probability mass left for "HOSTS BECOME" -- incrementing denominator
# warning: 0 backoff probability mass left for "PREDATORS BECOME" -- incrementing denominator
# warning: 0 backoff probability mass left for "NUISANCES BECOME" -- incrementing denominator
# warning: 0 backoff probability mass left for "PLANTS BECOME" -- incrementing denominator
# warning: 0 backoff probability mass left for "PRONE LESS" -- incrementing denominator
# warning: 0 backoff probability mass left for "<unk> SAILING" -- incrementing denominator
# warning: 0 backoff probability mass left for "LIVE HAWKS" -- incrementing denominator
# warning: 0 backoff probability mass left for "TREATMENTS IMMEDIATE" -- incrementing denominator
# warning: 0 backoff probability mass left for "PERENNIAL HERBACEOUS" -- incrementing denominator
# warning: 0 backoff probability mass left for "ABILITY BLOOD'S" -- incrementing denominator
# warning: 0 backoff probability mass left for "CALLED BLOCKS" -- incrementing denominator
# warning: 0 backoff probability mass left for "PART OUTER" -- incrementing denominator
# warning: 0 backoff probability mass left for "GROWS GRAPEFRUIT" -- incrementing denominator
# warning: 0 backoff probability mass left for "LESS WEIGHS" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAS AFRICA" -- incrementing denominator
# warning: 0 backoff probability mass left for "EACH TOWARD" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE QUACKS" -- incrementing denominator
# warning: 0 backoff probability mass left for "LEGS STOUT" -- incrementing denominator
# warning: 0 backoff probability mass left for "DISEASES MUSCLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "LAYERS MUSCLE" -- incrementing denominator
# warning: 0 backoff probability mass left for "WELL ADAPT" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE WORKMEN" -- incrementing denominator
# warning: 0 backoff probability mass left for "REQUIRES DECOMPOSITION" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE TROOPERS" -- incrementing denominator
# warning: 0 backoff probability mass left for "INTO SPERM" -- incrementing denominator
# warning: 0 backoff probability mass left for "HUMMINGBIRDS ATTRACTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "ATTENTION ATTRACTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "LEADS REACTION" -- incrementing denominator
# warning: 0 backoff probability mass left for "GIVES REACTION" -- incrementing denominator
# warning: 0 backoff probability mass left for "DIOXIDE RELEASES" -- incrementing denominator
# warning: 0 backoff probability mass left for "RESPIRATORY SAME" -- incrementing denominator
# warning: 0 backoff probability mass left for "TYPES NUMEROUS" -- incrementing denominator
# warning: 0 backoff probability mass left for "POSSIBLE IF" -- incrementing denominator
# warning: 0 backoff probability mass left for "AND IF" -- incrementing denominator
# warning: 0 backoff probability mass left for "NEEDED IF" -- incrementing denominator
# warning: 0 backoff probability mass left for "<unk> NONRELIGIOUS" -- incrementing denominator
# warning: 0 backoff probability mass left for "EYES IRRITATE" -- incrementing denominator
# warning: 0 backoff probability mass left for "WEIGHT SUPPORT" -- incrementing denominator
# warning: 0 backoff probability mass left for "HEALTH SUPPORT" -- incrementing denominator
# warning: 0 backoff probability mass left for "HEADS SUPPORT" -- incrementing denominator
# warning: 0 backoff probability mass left for "FAMILIES SUPPORT" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONCLUSIONS SUPPORT" -- incrementing denominator
# warning: 0 backoff probability mass left for "IDEAS SUPPORT" -- incrementing denominator
# warning: 0 backoff probability mass left for "THEORIES SUPPORT" -- incrementing denominator
# warning: 0 backoff probability mass left for "SUCH CROPS" -- incrementing denominator
# warning: 0 backoff probability mass left for "CUTS VIOLENCE" -- incrementing denominator
# warning: 0 backoff probability mass left for "TENDS VIOLENCE" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE IDIOTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "PREFERENCE EXHIBIT" -- incrementing denominator
# warning: 0 backoff probability mass left for "PATTERNS EXHIBIT" -- incrementing denominator
# warning: 0 backoff probability mass left for "EYES EXHIBIT" -- incrementing denominator
# warning: 0 backoff probability mass left for "MOVEMENT EXHIBIT" -- incrementing denominator
# warning: 0 backoff probability mass left for "BEHAVIOUR EXHIBIT" -- incrementing denominator
# warning: 0 backoff probability mass left for "AGGRESSIVE EXHIBIT" -- incrementing denominator
# warning: 0 backoff probability mass left for "REACTION EXHIBIT" -- incrementing denominator
# warning: 0 backoff probability mass left for "SMOKING CARELESS" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAS PARAGUAYAN" -- incrementing denominator
# warning: 0 backoff probability mass left for "SO NEARLY" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEMPERATURE RAISES" -- incrementing denominator
# warning: 0 backoff probability mass left for "FIND SUBSTANCES" -- incrementing denominator
# warning: 0 backoff probability mass left for "INTERFERE SUBSTANCES" -- incrementing denominator
# warning: 0 backoff probability mass left for "SUCH SUBSTANCES" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONSIST SUBSTANCES" -- incrementing denominator
# warning: 0 backoff probability mass left for "ACCUMULATE SUBSTANCES" -- incrementing denominator
# warning: 0 backoff probability mass left for "DERIVE SUBSTANCES" -- incrementing denominator
# warning: 0 backoff probability mass left for "INSTRUMENTS STRINGED" -- incrementing denominator
# warning: 0 backoff probability mass left for "COATS DARK" -- incrementing denominator
# warning: 0 backoff probability mass left for "FIND PROTEINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "INVOLVE PROTEINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONSIST PROTEINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "LEAD PROTEINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "DERIVE PROTEINS" -- incrementing denominator
# warning: 0 backoff probability mass left for "TEND COWS" -- incrementing denominator
# warning: 0 backoff probability mass left for "TERMITES KILLS" -- incrementing denominator
# warning: 0 backoff probability mass left for "ANTS KILLS" -- incrementing denominator
# warning: 0 backoff probability mass left for "ANIMALS KILLS" -- incrementing denominator
# warning: 0 backoff probability mass left for "BURROWS EXCAVATE" -- incrementing denominator
# warning: 0 backoff probability mass left for "<unk> PUNCTUATION" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAVE JOKERS" -- incrementing denominator
# warning: 0 backoff probability mass left for "FILL BATHS" -- incrementing denominator
# warning: 0 backoff probability mass left for "OPTIONS OFFER" -- incrementing denominator
# warning: 0 backoff probability mass left for "OPPORTUNITY OFFER" -- incrementing denominator
# warning: 0 backoff probability mass left for "DIVERSITY OFFER" -- incrementing denominator
# warning: 0 backoff probability mass left for "ENERGY BECOMES" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONCERN BECOMES" -- incrementing denominator
# warning: 0 backoff probability mass left for "PROBLEMS BECOMES" -- incrementing denominator
# warning: 0 backoff probability mass left for "SIT OWLS" -- incrementing denominator
# warning: 0 backoff probability mass left for "LIKE OWLS" -- incrementing denominator
# warning: 0 backoff probability mass left for "RETURN OWLS" -- incrementing denominator
# warning: 0 backoff probability mass left for "NEST OWLS" -- incrementing denominator
# warning: 0 backoff probability mass left for "RELY OWLS" -- incrementing denominator
# warning: 0 backoff probability mass left for "PREY OWLS" -- incrementing denominator
# warning: 0 backoff probability mass left for "COMBINES DIOXIDE" -- incrementing denominator
# warning: 0 backoff probability mass left for "BUILDS DIOXIDE" -- incrementing denominator
# warning: 0 backoff probability mass left for "DUE YEAR" -- incrementing denominator
# warning: 0 backoff probability mass left for "REFERS INTEGRITY" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAUL SEALS" -- incrementing denominator
# warning: 0 backoff probability mass left for "CONSIST TREATMENTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "ACCOUNT TREATMENTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "DEPEND TREATMENTS" -- incrementing denominator
# warning: 0 backoff probability mass left for "HAS SUMATRAN" -- incrementing denominator
# warning: 0 backoff probability mass left for "LEADS INTAKE" -- incrementing denominator
# warning: 0 backoff probability mass left for "COMES INTAKE" -- incrementing denominator
# warning: 0 backoff probability mass left for "RESULTS INTAKE" -- incrementing denominator
# warning: 0 backoff probability mass left for "SEASONS SURVIVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "ENVIRONMENTS SURVIVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "CLIMATES SURVIVE" -- incrementing denominator
# warning: 0 backoff probability mass left for "INFECTION SURVIVE" -- incrementing denominator
# discarded 24332 3-gram contexts containing pseudo-events
# writing 134376 1-grams
# writing 1240158 2-grams
# writing 3710847 3-grams
# Prune LM with threshold 1e-9
# /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/local/lm/lm_orig.arpa: line 79: warning: non-zero probability for <unk> in closed-vocabulary LM

# %% [markdown]
# ## Step 4: Build WFST decoder graph
#
# Convert the previous 3-gram language model into a WFST decoder graph.

# %%
# %%bash
#
# LM_ROOT=../LanguageModelDecoder/examples/speech/s0/
# LM_MODEL_DIR=/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model
# use_all_phones=0
# dict_type=phn
# sil_prob=0.9
#
# cd $LM_ROOT
# . path.sh
#
# # Prepare L.fst
# local/prepare_dict_ctc.sh $LM_MODEL_DIR/data/local/lm $LM_MODEL_DIR/data/local/dict_phn $use_all_phones
# tools/fst/ctc_compile_dict_token.sh --dict-type $dict_type --sil-prob $sil_prob \
#     $LM_MODEL_DIR/data/local/dict_phn $LM_MODEL_DIR/data/local/lang_phn_tmp $LM_MODEL_DIR/data/lang_phn
#
# # Build TLG decoding graph
# tools/fst/make_tlg.sh $LM_MODEL_DIR/data/local/lm $LM_MODEL_DIR/data/lang_phn $LM_MODEL_DIR/data/lang_test
# Out:
# /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/local/dict_phn
# lexicon_raw_nosil done
# units_nosil.txt done
# lexicon_numbers.txt done
# dict_type: phn
# space_char: >
# sil_prob: 0.9
# fstaddselfloops 'echo 42 |' 'echo 134374 |'
# Dict and token FSTs compiling succeeded
# arpa2fst --read-symbol-table=/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/lang_test/words.txt --keep-symbols=true -
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I0313 14:23:01.743629 1067173 arpa-file-parser.cc:93] Reading \data\ section.
# I0313 14:23:01.747021 1067173 arpa-file-parser.cc:148] Reading \1-grams: section.
# I0313 14:23:02.750360 1067173 arpa-file-parser.cc:148] Reading \2-grams: section.
# I0313 14:23:13.359136 1067173 arpa-file-parser.cc:148] Reading \3-grams: section.
# Checking how stochastic G is (the first of these numbers should be small):
# fstisstochastic /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/lang_test/G.fst
# 2.7294 -10.8701
# fstdeterminizestar --use-log=true
# fstminimizeencoded
# fsttablecompose /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/lang_test/L.fst /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/lang_test/G.fst
# fsttablecompose /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/lang_test/T.fst /hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/lang_test/LG.fst
# Composing decoding graph TLG.fst succeeded

# %%
g_fst_path = "/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/lang_test/G.fst"
lg_fst_path = "/hpi/fs00/scratch/leon.hermann/b2t/speechBCI/lm_model/data/lang_test/LG.fst"

import pynini

g_fst = pynini.Fst.read(g_fst_path)
lg_fst = pynini.Fst.read(lg_fst_path)
